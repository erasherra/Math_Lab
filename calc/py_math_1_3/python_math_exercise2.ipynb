# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as la
import math

# %% [markdown]
# <h3>1.</h3>

# %%
a = np.ones((5, 1))
b = np.array([np.arange(1,6)]).T

x = np.concatenate((a,
                    b,
                    np.power(b,2),
                    np.power(b,3),
                    np.power(b,4)),axis=1)

print(x)
# Out:
# [[  1.   1.   1.   1.   1.]
#  [  1.   2.   4.   8.  16.]
#  [  1.   3.   9.  27.  81.]
#  [  1.   4.  16.  64. 256.]
#  [  1.   5.  25. 125. 625.]]

# %% [markdown]
# <h3>2.<h3>

# %%
x1 = np.matrix(np.arange(1,11)).T
y1 = np.array([[14,12,34,24,43,38,41,57,55,50]]).T 

X = np.concatenate((np.ones((10, 1)),x1),axis= 1)
M = la.inv(X.T.dot(X)).dot(X.T).dot(y1)


print(M)
# Out:
# [[10.6       ]
#  [ 4.76363636]]

# %%
z = X.dot(M)
plt.plot(x1, z)
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# <h3>3.</h3>

# %%
x2 = np.power(x1,2)

X = np.concatenate((np.ones((10, 1)),x1,x2),axis= 1)
M = la.inv(X.T.dot(X)).dot(X.T).dot(y1)


print(M)
# Out:
# [[ 2.93333333]
#  [ 8.5969697 ]
#  [-0.34848485]]

# %%
z = X.dot(M)
plt.plot(x1, z)
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# <h3>4.</h3>

# %%
x = np.arange(1,11)
y = np.array([14,12,34,24,43,38,41,57,55,50])

coef = np.polyfit(x, y.T, 5)
p = np.poly1d(coef)

xx = np.linspace(1, 10, 1000)
yy = p(xx)
plt.plot(x, y, 'o')
plt.plot(xx, yy)
plt.show()
